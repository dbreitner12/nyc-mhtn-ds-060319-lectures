# %% [markdown]
# <h1 style='text-align:center'> Data VISHALization <h1/>

# %% [markdown]
# <img src='images/marshall.gif'/>

# %% [markdown]
# ## Why is Data Visualization Important?

# %%
import seaborn as sns
import pandas as pd

# %%
aq = pd.read_csv('aq.csv')

# %%
aq
# Out:
#       x1     y1    x2    y2    x3     y4    x5     y6
# 0   10.0   8.04  10.0  9.14  10.0   7.46   8.0   6.58
# 1    8.0   6.95   8.0  8.14   8.0   6.77   8.0   5.76
# 2   13.0   7.58  13.0  8.74  13.0  12.74   8.0   7.71
# 3    9.0   8.81   9.0  8.77   9.0   7.11   8.0   8.84
# 4   11.0   8.33  11.0  9.26  11.0   7.81   8.0   8.47
# 5   14.0   9.96  14.0  8.10  14.0   8.84   8.0   7.04
# 6    6.0   7.24   6.0  6.13   6.0   6.08   8.0   5.25
# 7    4.0   4.26   4.0  3.10   4.0   5.39  19.0  12.50
# 8   12.0  10.84  12.0  9.13  12.0   8.15   8.0   5.56
# 9    7.0   4.82   7.0  7.26   7.0   6.42   8.0   7.91
# 10   5.0   5.68   5.0  4.74   5.0   5.73   8.0   6.89

# %% [markdown]
# <h2> Men lie, women lie, numbers don't - Jay - Z</h2>
# <h3> But sometimes they do - Vishal </h3>

# %% [markdown]
# ##### Descriptive Statistics

# %%
descriptive_stats = pd.DataFrame([aq.mean(), aq.std(), aq.var()]).T

# %%
descriptive_stats
# Out:
#            0         1          2
# x1  9.000000  3.316625  11.000000
# y1  7.500909  2.031568   4.127269
# x2  9.000000  3.316625  11.000000
# y2  7.500909  2.031657   4.127629
# x3  9.000000  3.316625  11.000000
# y4  7.500000  2.030424   4.122620
# x5  9.000000  3.316625  11.000000
# y6  7.500909  2.030579   4.123249

# %% [markdown]
# ##### Graphs

# %%
sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# <img src='images/notsurprisedkirk.jpg'/>

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Matplotlib is a complex library (70,000 + lines of code!). In order to best understand how it creates graphs it's important to understand how objects are structured in matplotlib.

# %% [markdown]
# <img src='images/fig_map.webp'/>

# %% [markdown]
# ### Two Ways to Generate a Single Plot

# %%
plt.plot([1,2], [3,4])

# %%
fig, ax = plt.subplots()
ax.plot([1,2], [3,4])

# %% [markdown]
# #### How do we add a title to the above plot?

# %%
ax.set_title('Line')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(3.200000000000003, 0.5, 'Y Axis')

# %%
fig

# %% [markdown]
# ### Create a Figure with 2 Axes(Plots)

# %%
fig, ax = plt.subplots(1,2)
ax[0].barh([1,2], [3,4])
ax[1].scatter([1,2], [3,4])

# %%
#generate some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %% [markdown]
# #### create a figure with 2 x 2 plots

# %%
figure_sin, axes = plt.subplots(2,2, figsize=(10, 10))

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2d3b5080>,
# ...
#       dtype=object)

# %%
axes[0][0].scatter(x,y, color='orange')
axes[0][1].plot(x,y,'--')
axes[1][0].hist(y)
axes[1][1].fill(x,y)
axes[0][0].set_title('Scatter')
# Out:
# Text(0.5, 1.0, 'Scatter')

# %%
figure_sin

# %% [markdown]
# #### How can we create a title for the scatter plot?

# %%
axes[0][0].set_title('k')
# Out:
# Text(0.5, 1.0, 'k')

# %% [markdown]
# ## Seaborn

# %% [markdown]
# Seaborn is built on top of Matplotlib. Seaborn adds some styling to existing matplotlib graphs as well as adds some additional graphing capabilities.

# %%
import seaborn as sns
sns.set()

# %%
plt.plot([1,2], [3,4])

# %% [markdown]
# The most useful aspect of seaborn is that it allows you to use Pandas DataFrame Objects directly.

# %%
#Import Seaborn
import seaborn as sns

#Load tips dataset
tips = sns.load_dataset('tips')

#To get a glimpse of your dataset
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#x is the x-axis
#y is the y-axis
#data is your dataset
#hue is a grouping variable, can be numerical or categorical
#style is also a grouping variable, always categorical
#palette is your color style

scatter_plot = sns.scatterplot(x = 'total_bill', y ='tip', data = tips,
            hue = 'sex', style = 'time', palette = 'seismic')

# %%
#Intoduction to Seaborn
#Statistical plotting library built on Matplitlib
#Can create complex plots and works well with pandas dataframes
#conda install seaborn or pip install seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy
import warnings
warnings.filterwarnings('ignore')

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'], bins = 30)
#histogram plot, kde = kernel density estimation,
#if you dont want kernel density estimation line, 
#pass in argument kde = False
#bins argument is how many bars you want, can see the data more closely

# %%
sns.jointplot(x='total_bill'  , y='tip' , data = tips, kind ='scatter' )
#passing in two columns

# %%
sns.jointplot(x='total_bill'  , y='tip' , data = tips, kind ='hex' )

# %%
sns.jointplot(x='total_bill'  , y='tip' , data = tips, kind ='reg' )

# %%
sns.jointplot(x='total_bill'  , y='tip' , data = tips, kind ='kde' )

# %%
sns.pairplot(tips, hue ='sex')
#hue, pass in a categorical column
#building off joint plot, passes in dataset itself

# %%
sns.rugplot(tips['total_bill'])

# %%
# Categorical Plots
import numpy as np
sns.barplot(x='sex' , y='total_bill', data = tips, estimator = np.std)
#average total bill for sex
#x is categorical column
# y is numerial column
#estimator is a statistical function to estimate within each categorical bin
#standard dev for total bill column

# %%
sns.countplot(x= 'sex', data = tips)
#counts how many males and females

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Import Seaborn
import seaborn as sns

#Load tips dataset
tips = sns.load_dataset('tips')

#x is x-axis
#y is y-axis
#data is your dataset
#hue is a grouping variable, can be numerical or categorical
#palette is your color style
box_plot = sns.boxplot(x = 'sex', y = 'tip', data = tips, 
            hue = 'smoker', palette = 'muted')

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue ='sex', split = True)
#google what it is and when to use it
#kde of underlying estimation
#sees more about data points but harder to read than box plot
#very technical dat visualization

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = True)
#google jitter, adds more noise

# %%
sns.swarmplot(x = 'day', y ='total_bill', data = tips)
#similar to strip plot

# %%
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tc = tips.corr()

# %%
sns.heatmap(tc, annot=True, cmap = 'coolwarm')
#can see how numbers are relative to eachother

# %%
fp.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
#Load flights dataset
flights = sns.load_dataset('flights')

#Create pivot table
passenger_heat_map = flights.pivot(index = 'year', 
        columns = 'month', values = 'passengers')

#annot adds numbers to the heatmap
#annot_kws controls the size of the numbers
#fmt changes the numbers from scientific notation to integers
#cmap is a list of colors
#linecolor separates the heatmap
#linewidth is the size of the separation
sns.heatmap(passenger_heat_map, annot = True, annot_kws = {'size':10},
        fmt = 'g',cmap = 'seismic', linecolor = 'white', linewidths = 1)

# %%
flights = sns.load_dataset('fmri')
flights.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
planets_heat_map = planets.pivot_table(index = 'year', columns = 'mass', values = 'distance')
sns.heatmap(planets_heat_map, cmap = 'coolwarm', linecolor='white', linewidths =1 )

# %%
sns.clustermap(fp)
#clusters info to similar data

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
l = sns.FacetGrid(data = tips, col = 'time', row = 'smoker')
l.map(sns.distplot, 'total_bill')

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex',
          markers = ['o', 'v'], scatter_kws ={'s':100})

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, 
           col = 'day', hue = 'sex', aspect = 0.6, size = 8)

# %% [markdown]
# ## Resources

# %% [markdown]
# - https://www.ted.com/talks/david_mccandless_the_beauty_of_data_visualization#t-503926
# - https://realpython.com/python-matplotlib-guide/
# - https://www.darkhorseanalytics.com/blog/data-looks-better-naked/

# %% [markdown]
# ##### Vis Inspiration

# %% [markdown]
# - https://pudding.cool/
# - http://setosa.io/#/
